# %%
#!pip install moviepy
from moviepy.editor import *

video = VideoFileClip("Introducing YouTube Shorts.mp4")
video.write_gif("mon_gif.gif")
# Out:
# t:   2%|▏         | 124/7756 [08:15<26:49,  4.74it/s, now=None]
# MoviePy - Building file mon_gif.gif with imageio.
# ...
# t: 100%|██████████| 1233/1233 [02:07<00:00, 20.36it/s, now=None]
